# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Define a standard list of industries
Industries = [
    'Accommodation & Food Services',
    'Administrative & Support Services',
    'Community, Social & Personal Services',
    'Construction',
    'Financial & Insurance Services',
    'Information & Communications',
    'Manufacturing',
    'Professional Services',
    'Public Administration & Education Services',
    'Real Estate Services',
    'Transportation & Storage',
    'Wholesale & Retail Trade',
]

# Define a color palette for consistent visualization across charts
Palette = [
    '#636EFA',  # blue
    '#EF553B',  # red-orange
    '#00CC96',  # green
    '#AB63FA',  # purple
    '#FFA15A',  # orange
    '#19D3F3',  # light blue
    '#FF6692',  # pink
    '#B6E880',  # light green
    '#FF97FF',  # magenta
    '#FECB52',  # yellow
    '#2E91E5'   # bright blue
]

# Define the starting and ending years for the analysis
start_year = 2015
end_year = 2025
year_cols = [year for year in range(start_year, 2025)]

# %% [markdown]
# # Seif: Overall Employment By Industry

# %%
# Import data
df = pd.read_csv('M182081.csv')

# Clean data
df = df.dropna(thresh=2)
df.columns = ['Data Series'] + list(df.iloc[0,1:].astype(int))
df = df[['Data Series'] + year_cols]

# Filter selected industries only
df['Data Series'] = df['Data Series'].str.strip()
df['Data Series'] = df['Data Series'].replace('Other Community, Social & Personal Services', 'Community, Social & Personal Services')
df = df[df['Data Series'].isin(Industries)].reset_index(drop=True)
df = df.replace(['-', 'na', np.nan], 0)
df[year_cols] = df[year_cols].astype(float)
df = df.groupby('Data Series')[year_cols].sum().reset_index()

# Display cleaned
df = df.sort_values(by=['Data Series']).reset_index(drop=True)
display(df)
# Out:
#                                    Data Series   2015   2016   2017   2018  \
# 0                Accommodation & Food Services  278.4  276.3  268.7  268.8
# 1            Administrative & Support Services  217.8  231.7  229.4  235.7
# 2        Community, Social & Personal Services  134.2  129.8  131.0  134.2
# 3                                 Construction  221.2  202.3  201.5  208.8
# 4               Financial & Insurance Services  334.5  381.3  379.1  392.1
# 5                 Information & Communications  172.0  174.1  182.6  188.1
# 6                                Manufacturing  477.1  454.3  446.7  455.6
# 7                        Professional Services  333.2  325.9  341.5  348.8
# 8   Public Administration & Education Services  581.5  589.9  587.3  593.9
# 9                         Real Estate Services  110.8  107.0  115.2  108.0
# 10                    Transportation & Storage  375.3  376.7  391.9  397.9
# 11                    Wholesale & Retail Trade  728.2  728.2  712.4  705.0
#
#      2019   2020   2021   2022   2023   2024
# 0   263.6  257.7  250.5  253.3  279.1  295.0
# 1   240.0  256.6  239.9  240.6  250.3  248.0
# 2   128.3  130.8  147.2  139.6  142.7  146.0
# 3   196.1  194.5  196.8  195.4  188.5  205.8
# 4   418.7  415.9  450.5  471.7  472.5  478.9
# 5   205.2  222.8  240.8  265.6  271.8  278.4
# 6   428.7  426.0  424.2  449.9  423.8  424.3
# 7   363.1  362.9  393.1  395.3  399.7  394.2
# 8   608.6  587.9  631.2  619.2  611.2  611.4
# 9    97.4   99.6  102.1  119.4  114.5  112.6
# 10  411.0  429.6  401.3  414.8  428.7  395.7
# 11  712.0  670.3  677.2  703.6  671.6  672.2

# %%
# Melt the DataFrame for easier plotting
df_melted = df.melt(id_vars='Data Series', var_name='Year', value_name='Employed Residents')

# Plot line chart using Plotly Express
fig = px.line(df_melted, x='Year', y='Employed Residents', color='Data Series',
              title='Employed Residents By Industry Over Years',
              labels={'Employed Residents': 'Employed Residents (in thousands)', 'Data Series': 'Industry'},
              color_discrete_sequence = Palette)

fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Employed Residents (in thousands)',
    legend_title='Industry'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7d053567-894d-4797-8c5b-d28ba60e536b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d053567-894d-4797-8c5b-d28ba60e536b")) {                    Plotly.newPlot(                        "7d053567-894d-4797-8c5b-d28ba60e536b",                        [{"hovertemplate":"Industry=Accommodation & Food Services\u003cbr\u003eYear=%{x}\u003cbr\u003eEmployed Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accommodation & Food Services","line":{"color":"#636EFA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Accommodation & Food Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[278.4,276.3,268.7,268.8,263.6,257.7,250.5,253.3,279.1,295.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Administrative & Support Services\u003cbr\u003eYear=%{x}\u003cbr\u003eEmployed Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administrative & Support Services","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Administrative & Support Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[217.8,231.70000000000002,229.4,235.7,240.0,256.6,239.9,240.6,250.29999999999998,248.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Community, Social & Personal Services\u003cbr\u003eYear=%{x}\u003cbr\u003eEmployed Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Community, Social & Personal Services","line":{"color":"#00CC96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Community, Social & Personal Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[134.2,129.8,131.0,134.2,128.29999999999998,130.8,147.2,139.6,142.7,146.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Construction\u003cbr\u003eYear=%{x}\u003cbr\u003eEmployed Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Construction","line":{"color":"#AB63FA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Construction","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[221.2,202.3,201.5,208.8,196.1,194.5,196.8,195.4,188.5,205.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Financial & Insurance Services\u003cbr\u003eYear=%{x}\u003cbr\u003eEmployed Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Financial & Insurance Services","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Financial & Insurance Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[334.5,381.29999999999995,379.1,392.1,418.7,415.90000000000003,450.5,471.7,472.5,478.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Information & Communications\u003cbr\u003eYear=%{x}\u003cbr\u003eEmployed Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Information & Communications","line":{"color":"#19D3F3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Information & Communications","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[172.0,174.1,182.6,188.1,205.2,222.8,240.8,265.6,271.8,278.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Manufacturing\u003cbr\u003eYear=%{x}\u003cbr\u003eEmployed Residents (in thousands)=%{y}\u003ce ...

# %% [markdown]
# # Timothy: Employment by Industry and Gender

# %%
# Import data
df = pd.read_csv('M182141.csv')

# Clean data
df = df.dropna(thresh=2)
df.columns = ['Data Series'] + list(df.iloc[0,1:].astype(int))
df = df[['Data Series'] + year_cols]

# Filter selected industries only
df['Data Series'] = df['Data Series'].str.strip()
df['Data Series'] = df['Data Series'].replace('Other Community, Social & Personal Services', 'Community, Social & Personal Services')
df['Data Series'] = df['Data Series'].replace('All Industries (Employed Male Residents)', 'Total')
df = df[df['Data Series'].isin(['Total'] + Industries)].reset_index(drop=True)
df = df.replace(['-', 'na', np.nan], 0)
df[year_cols] = df[year_cols].astype(float)
df = df.groupby('Data Series')[year_cols].sum().reset_index()

# Display cleaned
male_df = df.sort_values(by=['Data Series']).reset_index(drop=True)
display(male_df)
# Out:
#                               Data Series    2015    2016    2017    2018  \
# 0           Accommodation & Food Services   122.1   120.0   121.0   118.7
# 1       Administrative & Support Services   121.1   132.9   125.8   136.9
# 2   Community, Social & Personal Services    57.0    54.5    54.7    55.4
# 3                            Construction   161.1   146.9   144.2   153.3
# 4          Financial & Insurance Services   157.1   181.2   181.5   189.1
# 5            Information & Communications   103.2   104.8   113.6   110.3
# 6                           Manufacturing   306.9   291.0   290.3   289.7
# 7                   Professional Services   174.0   169.0   177.6   184.4
# 8                    Real Estate Services    54.7    57.2    56.2    55.7
# 9                                   Total  1171.8  1178.4  1189.4  1197.2
# 10               Transportation & Storage   282.8   286.3   305.8   301.9
# 11               Wholesale & Retail Trade   370.2   368.9   365.9   352.9
#
#       2019    2020    2021    2022    2023    2024
# 0    116.3   111.7   110.4   109.5   124.0   125.0
# 1    133.7   150.8   139.6   141.0   140.3   144.0
# 2     55.3    51.7    62.7    59.8    62.3    58.0
# 3    142.2   138.0   137.4   137.4   132.2   145.4
# 4    207.8   200.3   221.8   235.0   234.7   226.1
# 5    120.3   132.9   140.9   158.7   159.8   159.1
# 6    273.7   270.2   263.4   283.3   260.5   264.5
# 7    187.3   193.1   201.8   208.6   202.1   202.2
# 8     47.9    47.8    48.3    58.9    57.0    56.8
# 9   1202.5  1198.1  1220.3  1256.2  1244.0  1238.0
# 10   312.0   324.5   302.2   305.1   324.9   303.6
# 11   363.6   335.1   338.3   348.3   339.5   324.8

# %%
# Import data
df = pd.read_csv('M182151.csv')

# Clean data
df = df.dropna(thresh=2)
df.columns = ['Data Series'] + list(df.iloc[0,1:].astype(int))
df = df[['Data Series'] + year_cols]

# Filter selected industries only
df['Data Series'] = df['Data Series'].str.strip()
df['Data Series'] = df['Data Series'].replace('Other Community, Social & Personal Services', 'Community, Social & Personal Services')
df['Data Series'] = df['Data Series'].replace('All Industries (Employed Female Residents)', 'Total')
df = df[df['Data Series'].isin(['Total'] + Industries)].reset_index(drop=True)
df = df.replace(['-', 'na', np.nan], 0)
df[year_cols] = df[year_cols].astype(float)
df = df.groupby('Data Series')[year_cols].sum().reset_index()

# Display cleaned
female_df = df.sort_values(by=['Data Series']).reset_index(drop=True)
display(df)
# Out:
#                               Data Series   2015   2016   2017    2018  \
# 0           Accommodation & Food Services  156.2  156.2  147.7   150.0
# 1       Administrative & Support Services   96.7   98.9  103.9    98.9
# 2   Community, Social & Personal Services   77.2   75.2   76.4    78.7
# 3                            Construction   60.0   55.6   57.3    55.5
# 4          Financial & Insurance Services  177.4  200.2  197.5   203.2
# 5            Information & Communications   68.8   69.1   69.3    77.8
# 6                           Manufacturing  170.2  163.3  156.4   165.8
# 7                   Professional Services  159.2  157.0  164.0   164.6
# 8                    Real Estate Services   56.0   49.8   59.0    52.4
# 9                                   Total  976.0  986.9  985.9  1006.5
# 10               Transportation & Storage   92.4   90.5   85.9    96.1
# 11               Wholesale & Retail Trade  357.8  359.4  346.6   352.2
#
#       2019    2020    2021    2022    2023    2024
# 0    147.2   146.1   140.1   143.5   155.3   169.6
# 1    106.4   106.0   100.3    99.7   110.2   103.9
# 2     73.0    79.4    84.2    79.8    80.4    87.9
# 3     53.9    56.7    59.6    57.8    56.4    60.2
# 4    210.9   215.5   228.7   236.7   237.8   252.6
# 5     85.1    90.1    99.8   107.0   112.3   119.2
# 6    155.2   155.7   160.6   166.4   163.5   160.1
# 7    175.8   169.6   191.3   186.8   197.5   192.0
# 8     49.4    51.9    53.6    60.4    57.8    55.8
# 9   1027.9  1024.6  1066.2  1094.2  1108.3  1127.6
# 10    99.0   105.3    99.0   109.6   103.5    92.5
# 11   348.7   335.1   339.1   355.4   332.3   347.2

# %%
# Combine and melt dataframes
male_df_melted = male_df.melt(id_vars='Data Series', var_name='Year', value_name='Male Employment')
female_df_melted = female_df.melt(id_vars='Data Series', var_name='Year', value_name='Female Employment')
combined_df = pd.merge(male_df_melted, female_df_melted, on=['Data Series', 'Year'])

display(combined_df)
# Out:
#                                Data Series  Year  Male Employment  \
# 0            Accommodation & Food Services  2015            122.1
# 1        Administrative & Support Services  2015            121.1
# 2    Community, Social & Personal Services  2015             57.0
# 3                             Construction  2015            161.1
# 4           Financial & Insurance Services  2015            157.1
# ..                                     ...   ...              ...
# 115                  Professional Services  2024            202.2
# 116                   Real Estate Services  2024             56.8
# 117                                  Total  2024           1238.0
# 118               Transportation & Storage  2024            303.6
# 119               Wholesale & Retail Trade  2024            324.8
#
#      Female Employment
# 0                156.2
# 1                 96.7
# 2                 77.2
# 3                 60.0
# 4                177.4
# ..                 ...
# 115              192.0
# 116               55.8
# 117             1127.6
# 118               92.5
# 119              347.2
#
# [120 rows x 4 columns]

# %%
# Aggregate total male and female employment for each year across industries
df_to_plot = combined_df.groupby('Year')[['Male Employment', 'Female Employment']].sum().reset_index()

# Create Stacked Bar Chart
fig = px.bar(df_to_plot, x='Year', y=['Male Employment', 'Female Employment'],
             title='Total Male and Female Employed Residents Over Years',
             labels={'Year': 'Year', 'value': 'Employed Residents (in thousands)', 'variable': 'Gender'},
             color_discrete_sequence=['#ADD8E6', '#FFB6C1'])

fig.update_layout(barmode='group')
fig.update_xaxes(tickmode='linear')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="30094cfb-91fd-48f3-8a57-a40e5f4ffecd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30094cfb-91fd-48f3-8a57-a40e5f4ffecd")) {                    Plotly.newPlot(                        "30094cfb-91fd-48f3-8a57-a40e5f4ffecd",                        [{"alignmentgroup":"True","hovertemplate":"Gender=Male Employment\u003cbr\u003eYear=%{x}\u003cbr\u003eEmployed Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male Employment","marker":{"color":"#ADD8E6","pattern":{"shape":""}},"name":"Male Employment","offsetgroup":"Male Employment","orientation":"v","showlegend":true,"textposition":"auto","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[3082.0,3091.1000000000004,3126.0,3145.5,3162.6,3154.2,3187.1,3301.8,3281.2999999999997,3247.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=Female Employment\u003cbr\u003eYear=%{x}\u003cbr\u003eEmployed Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female Employment","marker":{"color":"#FFB6C1","pattern":{"shape":""}},"name":"Female Employment","offsetgroup":"Female Employment","orientation":"v","showlegend":true,"textposition":"auto","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2447.9,2462.1,2449.9,2501.7,2532.5,2536.0,2622.5,2697.3,2715.3,2768.6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0. ...

# %%
# Calculate proportion for 100% stacked area
df_to_plot = combined_df.groupby('Year')[['Male Employment', 'Female Employment']].sum().reset_index()
df_to_plot['Male Employment'] = df_to_plot['Male Employment'] / (df_to_plot['Male Employment'] + df_to_plot['Female Employment'])
df_to_plot['Female Employment'] = df_to_plot['Female Employment'] / (df_to_plot['Male Employment'] + df_to_plot['Female Employment'])

# Melt into long format for area chart
df_to_plot = df_to_plot.melt(id_vars='Year', var_name='Gender', value_name='Proportion')

# Create 100% Stacked Area Chart for Professional Services using Plotly Express
fig = px.area(df_to_plot, x='Year', y='Proportion', color='Gender',
              color_discrete_sequence=['#ADD8E6', '#FFB6C1'],
              title='Male and Female Employment Proportion in Professional Services (2015-2024)',
              labels={'Year': 'Year', 'Proportion': 'Proportion of Employed Residents', 'Gender': 'Gender'})

fig.update_layout(yaxis=dict(range=[0, 1],dtick=0.1))  # Set y-axis range from 0 to 1 for 100%
fig.update_xaxes(tickmode='linear')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="51f3abbc-a89e-438e-af03-c3df196a36b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51f3abbc-a89e-438e-af03-c3df196a36b5")) {                    Plotly.newPlot(                        "51f3abbc-a89e-438e-af03-c3df196a36b5",                        [{"fillpattern":{"shape":""},"hovertemplate":"Gender=Male Employment\u003cbr\u003eYear=%{x}\u003cbr\u003eProportion of Employed Residents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male Employment","line":{"color":"#ADD8E6"},"marker":{"symbol":"circle"},"mode":"lines","name":"Male Employment","orientation":"v","showlegend":true,"stackgroup":"1","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[0.5573337673375649,0.5566340128214363,0.5606269839846483,0.557001699957501,0.5553194851714631,0.554321464974869,0.5485919856788762,0.5503825573836075,0.5471934095987726,0.5398015325543125],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Gender=Female Employment\u003cbr\u003eYear=%{x}\u003cbr\u003eProportion of Employed Residents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female Employment","line":{"color":"#FFB6C1"},"marker":{"symbol":"circle"},"mode":"lines","name":"Female Employment","orientation":"v","showlegend":true,"stackgroup":"1","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[0.9997723735024289,0.9997739701080801,0.9997712156735713,0.9997774002831926,0.9997807708813544,0.9997814667479092,0.9997908571014068,0.9997959921866156,0.999798518336773,0.9998050652653016],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar": ...

# %% [markdown]
# # Nabodita: Employment by Education Level

# %%
# Import data
df = pd.read_csv('M182271.csv')

# Clean data
df = df.dropna(thresh=2)
df.columns = ['Data Series'] + list(df.iloc[0,1:].astype(int))
df = df.iloc[2:7][['Data Series'] + year_cols]
df['Data Series'] = df['Data Series'].str.strip()
df['Data Series'] = df['Data Series'].replace('Post-Secondary (Non-Tertiary)', 'Post-Secondary')

# Display cleaned
df.reset_index(drop=True, inplace=True)
display(df)
# Out:
#                             Data Series   2015   2016   2017   2018   2019  \
# 0                       Below Secondary  407.3  411.5  398.9  365.0  352.0
# 1                             Secondary  406.8  386.6  374.0  375.9  373.3
# 2                        Post-Secondary  267.7  260.3  257.1  264.3  261.8
# 3  Diploma & Professional Qualification  431.1  438.7  429.5  446.7  468.7
# 4                                Degree  719.4  760.4  810.1  841.0  872.7
#
#     2020   2021    2022    2023    2024
# 0  334.8  311.6   309.5   297.3   279.6
# 1  360.8  344.0   340.3   330.5   323.3
# 2  269.3  267.8   278.1   278.1   282.0
# 3  464.3  484.1   495.7   497.4   501.1
# 4  916.3  990.3  1014.2  1032.9  1060.5

# %%
# Melt the DataFrame for easier plotting
df_long = df.melt(id_vars='Data Series', var_name='Year', value_name='Value')

# Define the desired order of education levels
edu_order = ['Degree', 'Diploma & Professional Qualification', 'Post-Secondary', 'Secondary', 'Below Secondary']

# Convert 'Year' to numeric, coercing errors and then to integer
df_long['Year'] = pd.to_numeric(df_long['Year'], errors='coerce').astype(int)

# Drop rows where 'Year' is NaN after coercion
df_long.dropna(subset=['Year'], inplace=True)

# Create stacked bar chart using Plotly Express
fig = px.bar(df_long, x='Year', y='Value', color='Data Series', color_discrete_sequence=px.colors.sequential.Viridis,
             title='Labour Force by Education Level Over Years',
             labels={'Year': 'Year', 'Value': 'Number of Residents (in thousands)', 'Data Series': 'Education Level'},
             category_orders={'Data Series': edu_order})

fig.update_layout(barmode='stack')
fig.update_xaxes(tickmode='linear')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="46c668f6-84fb-4ee2-9aa4-621195a53462" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46c668f6-84fb-4ee2-9aa4-621195a53462")) {                    Plotly.newPlot(                        "46c668f6-84fb-4ee2-9aa4-621195a53462",                        [{"alignmentgroup":"True","hovertemplate":"Education Level=Degree\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Degree","marker":{"color":"#440154","pattern":{"shape":""}},"name":"Degree","offsetgroup":"Degree","orientation":"v","showlegend":true,"textposition":"auto","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[719.4,760.4,810.1,841.0,872.7,916.3,990.3,1014.2,1032.9,1060.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=Diploma & Professional Qualification\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Diploma & Professional Qualification","marker":{"color":"#482878","pattern":{"shape":""}},"name":"Diploma & Professional Qualification","offsetgroup":"Diploma & Professional Qualification","orientation":"v","showlegend":true,"textposition":"auto","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[431.1,438.7,429.5,446.7,468.7,464.3,484.1,495.7,497.4,501.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=Post-Secondary\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Post-Secondary","marker":{"color":"#3e4989","pattern":{"shape":""}},"name":"Post-Secondary","offsetgroup":"Post-Secondary","orientation":"v","showlegend":true,"textposition":"auto","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[267.7,260.3,257.1,264.3,261.8,269.3,267.8,278.1,278.1,282.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=Secondary\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Secondary","marker":{"color":"#31688e","pattern":{"shape":""}},"name":"Secondary","offsetgroup":"Secondary","orientation":"v","showlegend":true,"textposition":"auto","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[406.8,386.6,374.0,375.9,373.3,360.8,344.0,340.3,330.5,323.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Education Level=Below Secondary\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Residents (in thousands)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Below Secondary","marker":{"color":"#26828e","pattern":{"shape":""}},"name":"Below Secondary","offsetgroup":"Below Secondary","orientation":"v","showlegend":true,"textposition":"auto","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[407.3,411.5,398.9,365.0,352.0,334.8,311.6,309.5,297.3,279.6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...

# %%
# Calculate the share of each education level
df_pivot = df_long.pivot(index='Year', columns='Data Series', values='Value').fillna(0)
df_share = df_pivot.div(df_pivot.sum(axis=1), axis=0).reset_index().melt(id_vars='Year', var_name='Data Series', value_name='Proportion')

# Generate 100% stacked bar chart using Plotly Express
fig = px.area(df_share, x='Year', y='Proportion', color='Data Series', color_discrete_sequence=px.colors.sequential.Viridis,
              title='Education Level Share of Labour Force Over Years',
              labels={'Year': 'Year', 'Proportion': 'Proportion of Employed Residents', 'Data Series': 'Education Level'},
              category_orders={'Data Series': edu_order})

fig.update_layout(barmode='stack', yaxis=dict(range=[0, 1])) # Set y-axis range from 0 to 1 for 100% and barmode to stack
fig.update_xaxes(tickmode='linear')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8f97b319-5e2b-4340-8600-303d41891e43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f97b319-5e2b-4340-8600-303d41891e43")) {                    Plotly.newPlot(                        "8f97b319-5e2b-4340-8600-303d41891e43",                        [{"fillpattern":{"shape":""},"hovertemplate":"Education Level=Degree\u003cbr\u003eYear=%{x}\u003cbr\u003eProportion of Employed Residents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Degree","line":{"color":"#440154"},"marker":{"symbol":"circle"},"mode":"lines","name":"Degree","orientation":"v","showlegend":true,"stackgroup":"1","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[0.32226851229673426,0.3368327796234773,0.3569351427564329,0.36678442147498796,0.37479063774962423,0.39066297164783625,0.4130035866210693,0.41603084748543767,0.42397996880387495,0.4334763948497854],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Education Level=Diploma & Professional Qualification\u003cbr\u003eYear=%{x}\u003cbr\u003eProportion of Employed Residents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Diploma & Professional Qualification","line":{"color":"#482878"},"marker":{"symbol":"circle"},"mode":"lines","name":"Diploma & Professional Qualification","orientation":"v","showlegend":true,"stackgroup":"1","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[0.19311920440800967,0.19433001107419712,0.18924039478322172,0.19481878843386102,0.20128838307923555,0.1979535280324025,0.2018934022854283,0.20333907621626054,0.20417042935719565,0.20482321684038424],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Education Level=Post-Secondary\u003cbr\u003eYear=%{x}\u003cbr\u003eProportion of Employed Residents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Post-Secondary","line":{"color":"#3e4989"},"marker":{"symbol":"circle"},"mode":"lines","name":"Post-Secondary","orientation":"v","showlegend":true,"stackgroup":"1","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[0.11992115755050843,0.1153045404208195,0.11327987310539303,0.11526887347900039,0.11243289671462316,0.11481560434875293,0.11168571190257735,0.11407826729017967,0.11415318939331748,0.11526670754138565],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Education Level=Secondary\u003cbr\u003eYear=%{x}\u003cbr\u003eProportion of Employed Residents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Secondary","line":{"color":"#31688e"},"marker":{"symbol":"circle"},"mode":"lines","name":"Secondary","orientation":"v","showlegend":true,"stackgroup":"1","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[0.18223357075661872,0.1712513842746401,0.16478674656327108,0.1639408609184875,0.16031780115954478,0.1538264762310808,0.14346484277254148,0.13959307572401344,0.13566209670798787,0.13214796648273044],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Education Level=Below Secondary\u003cbr\u003eYear=%{x}\u003cbr\u003eProportion of Employed Residents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Below Secondary","line":{"color":"#26828e"},"marker":{"symbol":"circle"},"mode":"lines","name":"Below Secondary","orientation":"v","showlegend":true,"stackgroup":"1","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[0.18245755498812882,0.182281284606866,0.17575784279168136,0.15918705569366304,0.1511702812969723,0.14274141973992752,0.12995245641838352,0.12695873328410862,0.12203431573762419,0.1142857142857143],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"his ...

# %% [markdown]
# # Vedika: Employment by Industry and Workload

# %%
# Import data
df = pd.read_csv('M184061.csv')

# Clean data
df = df.dropna(thresh=2)
df.columns = ['Data Series'] + list(df.iloc[0,1:].astype(int))
df = df[['Data Series'] + year_cols]

# Filter selected industries only
df['Data Series'] = df['Data Series'].str.strip()
df['Data Series'] = df['Data Series'].replace('Other Community, Social & Personal Services', 'Community, Social & Personal Services')
df = df[df['Data Series'].isin(Industries)].reset_index(drop=True)
df = df.replace(['-', 'na', np.nan], 0)
df[year_cols] = df[year_cols].astype(float)
df = df.groupby('Data Series')[year_cols].sum().reset_index()

# Display cleaned
df1 = df.sort_values(by=['Data Series']).reset_index(drop=True)
display(df1)
# Out:
#                               Data Series  2015  2016  2017  2018  2019  2020  \
# 0           Accommodation & Food Services  41.5  42.0  42.2  41.5  41.8  40.9
# 1       Administrative & Support Services  46.5  46.7  46.9  46.0  46.0  45.3
# 2   Community, Social & Personal Services  42.1  42.1  41.9  41.8  41.9  41.7
# 3                            Construction  52.1  52.0  50.8  50.4  50.0  48.1
# 4          Financial & Insurance Services  41.1  41.1  41.1  41.1  41.6  41.3
# 5            Information & Communications  41.5  41.4  41.5  41.7  41.6  41.5
# 6                           Manufacturing  49.2  48.9  48.5  48.3  47.8  46.9
# 7                   Professional Services  42.9  43.3  43.1  43.0  42.9  42.4
# 8                    Real Estate Services  44.8  45.0  44.6  44.0  44.2  43.6
# 9                Transportation & Storage  45.7  45.9  45.5  45.6  45.5  45.1
# 10               Wholesale & Retail Trade  43.0  42.7  42.8  42.9  42.9  42.7
#
#     2021  2022  2023  2024
# 0   40.5  40.4  40.2  40.2
# 1   44.8  43.6  43.7  43.1
# 2   41.7  41.8  41.6  41.3
# 3   49.8  49.9  48.6  47.8
# 4   41.7  41.3  40.8  40.6
# 5   41.4  40.9  40.6  40.7
# 6   47.8  47.5  46.5  45.9
# 7   42.4  42.6  42.3  42.7
# 8   43.4  43.2  43.2  43.4
# 9   45.4  45.2  44.3  43.8
# 10  42.4  42.2  41.4  41.3

# %%
# Import data
df = pd.read_csv('M184091.csv')

# Clean data
df = df.dropna(thresh=2)
df.columns = ['Data Series'] + list(df.iloc[0,1:].astype(int))
df = df.iloc[1:][['Data Series'] + year_cols]
df['Data Series'] = df['Data Series'].str.strip()
df['Data Series'] = df['Data Series'].replace('Post-Secondary (Non-Tertiary)', 'Post-Secondary')
df2 = df.replace(['-', 'na', np.nan], 0)
df2[year_cols] = df2[year_cols].astype(float)

# Display cleaned
df2.reset_index(drop=True, inplace=True)
display(df2)
# Out:
#                                          Data Series  2015  2016  2017  2018  \
# 0           Mean Usual Hours Worked Per Week (Hours)  44.2  43.4  43.2  43.0
# 1  Percentage Of Workers Who Usually Worked At Le...  84.8  84.7  84.3  83.6
#
#    2019  2020  2021  2022  2023  2024
# 0  42.9  42.8  42.4  42.2  41.9  41.6
# 1  83.6  82.9  83.5  83.2  83.8   0.0

# %%
# Melt df1
df1_melted = df1.melt(id_vars='Data Series', var_name='Year', value_name='Avg paid working hrs per week')

# Melt df2
df2_melted = df2.melt(id_vars='Data Series', var_name='Year', value_name='Value')

# Pivot df2 to wide format
df2_wide = df2_melted.pivot(index='Year', columns='Data Series', values='Value').reset_index()

# Combine dataframe
df = df1_melted.merge(df2_wide, on='Year', how='left')
df['Hours_Gap'] = df['Mean Usual Hours Worked Per Week (Hours)'] - df['Avg paid working hrs per week']

# Display Combined DataFrame
display(df)
# Out:
#                                Data Series  Year  \
# 0            Accommodation & Food Services  2015
# 1        Administrative & Support Services  2015
# 2    Community, Social & Personal Services  2015
# 3                             Construction  2015
# 4           Financial & Insurance Services  2015
# ..                                     ...   ...
# 105                          Manufacturing  2024
# 106                  Professional Services  2024
# 107                   Real Estate Services  2024
# 108               Transportation & Storage  2024
# 109               Wholesale & Retail Trade  2024
#
#      Avg paid working hrs per week  Mean Usual Hours Worked Per Week (Hours)  \
# 0                             41.5                                      44.2
# 1                             46.5                                      44.2
# 2                             42.1                                      44.2
# 3                             52.1                                      44.2
# 4                             41.1                                      44.2
# ..                             ...                                       ...
# 105                           45.9                                      41.6
# 106                           42.7                                      41.6
# 107                           43.4                                      41.6
# 108                           43.8                                      41.6
# 109                           41.3                                      41.6
#
#      Percentage Of Workers Who Usually Worked At Least 40 Hours Per Week (Per Cent)  \
# 0                                                 84.8
# 1                                                 84.8
# 2                                                 84.8
# 3                                                 84.8
# 4                                                 84.8
# ..                                                 ...
# 105                                                0.0
# 106                                                0.0
# 107                                                0.0
# 108                                                0.0
# 109                                                0.0
#
#      Hours_Gap
# 0          2.7
# 1         -2.3
# 2          2.1
# 3         -7.9
# 4          3.1
# ..         ...
# 105       -4.3
# 106       -1.1
# 107       -1.8
# 108       -2.2
# 109        0.3
#
# [110 rows x 6 columns]

# %%
# Generate line chart for Hours_Gap over the years by Data Series using Plotly Express
fig = px.line(df, x='Year', y='Hours_Gap', color='Data Series',
              title='Hours Gap Over the Years by Industry',
              labels={'Year': 'Year', 'Hours_Gap': 'Hours Gap', 'Data Series': 'Industry'},
              color_discrete_sequence = Palette)

# Add a dashed line at 0
fig.add_shape(type='line', x0=df['Year'].min(), x1=df['Year'].max(), y0=0, y1=0,
              line=dict(color='black', width=1.5, dash='dash'))

fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Hours Gap',
    legend_title='Industry'
)

fig.update_xaxes(tickmode='linear')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4253ac0b-67b6-450d-8a15-8c1038b9c9bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4253ac0b-67b6-450d-8a15-8c1038b9c9bd")) {                    Plotly.newPlot(                        "4253ac0b-67b6-450d-8a15-8c1038b9c9bd",                        [{"hovertemplate":"Industry=Accommodation & Food Services\u003cbr\u003eYear=%{x}\u003cbr\u003eHours Gap=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accommodation & Food Services","line":{"color":"#636EFA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Accommodation & Food Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2.700000000000003,1.3999999999999986,1.0,1.5,1.1000000000000014,1.8999999999999986,1.8999999999999986,1.8000000000000043,1.6999999999999957,1.3999999999999986],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Administrative & Support Services\u003cbr\u003eYear=%{x}\u003cbr\u003eHours Gap=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administrative & Support Services","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Administrative & Support Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[-2.299999999999997,-3.3000000000000043,-3.6999999999999957,-3.0,-3.1000000000000014,-2.5,-2.3999999999999986,-1.3999999999999986,-1.8000000000000043,-1.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Community, Social & Personal Services\u003cbr\u003eYear=%{x}\u003cbr\u003eHours Gap=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Community, Social & Personal Services","line":{"color":"#00CC96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Community, Social & Personal Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2.1000000000000014,1.2999999999999972,1.3000000000000043,1.2000000000000028,1.0,1.0999999999999943,0.6999999999999957,0.4000000000000057,0.29999999999999716,0.30000000000000426],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Construction\u003cbr\u003eYear=%{x}\u003cbr\u003eHours Gap=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Construction","line":{"color":"#AB63FA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Construction","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[-7.899999999999999,-8.600000000000001,-7.599999999999994,-7.399999999999999,-7.100000000000001,-5.300000000000004,-7.399999999999999,-7.699999999999996,-6.700000000000003,-6.199999999999996],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Financial & Insurance Services\u003cbr\u003eYear=%{x}\u003cbr\u003eHours Gap=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Financial & Insurance Services","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Financial & Insurance Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[3.1000000000000014,2.299999999999997,2.1000000000000014,1.8999999999999986,1.2999999999999972,1.5,0.6999999999999957,0.9000000000000057,1.1000000000000014,1.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Information & Communications\u003cbr\u003eYear=%{x}\u003cbr\u003eHours Gap=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Information & Communications","line":{"color":"#19D3F3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Information & Communic ...

# %%
# Prepare data for heatmap - pivot table with Data Series as index, Year as columns, and Avg paid working hrs as values
heatmap_data = df.pivot_table(
    index='Data Series',
    columns='Year',
    values='Avg paid working hrs per week',
    aggfunc='mean'
)

# Generate heatmap using Plotly Express
fig = px.imshow(heatmap_data,
                labels=dict(x="Year", y="Industry", color="Avg Paid Working Hours"),
                x=heatmap_data.columns.tolist(),
                y=heatmap_data.index.tolist(),
                title='Average Paid Working Hours per Week by Industry and Year',
                text_auto=True,
                color_continuous_scale=px.colors.sequential.Viridis)

fig.update_xaxes(side="top")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5eff31d9-56c5-45fb-abf9-5a6941bad989" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5eff31d9-56c5-45fb-abf9-5a6941bad989")) {                    Plotly.newPlot(                        "5eff31d9-56c5-45fb-abf9-5a6941bad989",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"y":["Accommodation & Food Services","Administrative & Support Services","Community, Social & Personal Services","Construction","Financial & Insurance Services","Information & Communications","Manufacturing","Professional Services","Real Estate Services","Transportation & Storage","Wholesale & Retail Trade"],"z":[[41.5,42.0,42.2,41.5,41.8,40.9,40.5,40.4,40.2,40.2],[46.5,46.7,46.9,46.0,46.0,45.3,44.8,43.6,43.7,43.1],[42.1,42.1,41.9,41.8,41.9,41.7,41.7,41.8,41.6,41.3],[52.1,52.0,50.8,50.4,50.0,48.1,49.8,49.9,48.6,47.8],[41.1,41.1,41.1,41.1,41.6,41.3,41.7,41.3,40.8,40.6],[41.5,41.4,41.5,41.7,41.6,41.5,41.4,40.9,40.6,40.7],[49.2,48.9,48.5,48.3,47.8,46.9,47.8,47.5,46.5,45.9],[42.9,43.3,43.1,43.0,42.9,42.4,42.4,42.6,42.3,42.7],[44.8,45.0,44.6,44.0,44.2,43.6,43.4,43.2,43.2,43.4],[45.7,45.9,45.5,45.6,45.5,45.1,45.4,45.2,44.3,43.8],[43.0,42.7,42.8,42.9,42.9,42.7,42.4,42.2,41.4,41.3]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Year: %{x}\u003cbr\u003eIndustry: %{y}\u003cbr\u003eAvg Paid Working Hours: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333333 ...

# %% [markdown]
# # Delwin: Employment by Industry and Income

# %%
# Import Data
df = pd.read_csv('FT_Res_ind_income.csv')

# Filter year range
df = df[df['year'].isin(list(map(str, year_cols)))]
df['year'] = df['year'].astype(int)

# Filter selected industries
df['industry'] = df['industry'].str.title()
df['industry'] = df['industry'].replace('Other Community, Social & Personal Services', 'Community, Social & Personal Services')
df = df[df['industry'].isin(Industries)]

# Display cleaned
df_income = df.sort_values(by=['year','industry']).reset_index(drop=True)
display(df_income)
# Out:
#      year                               industry  \
# 0    2015          Accommodation & Food Services
# 1    2015      Administrative & Support Services
# 2    2015  Community, Social & Personal Services
# 3    2015                           Construction
# 4    2015         Financial & Insurance Services
# ..    ...                                    ...
# 105  2024                          Manufacturing
# 106  2024                  Professional Services
# 107  2024                   Real Estate Services
# 108  2024               Transportation & Storage
# 109  2024               Wholesale & Retail Trade
#
#      median_gross_monthly_income_including_employer_cpf  \
# 0                                                 2000
# 1                                                 2238
# 2                                                 2662
# 3                                                 3790
# 4                                                 6338
# ..                                                 ...
# 105                                               5850
# 106                                               6900
# 107                                               4908
# 108                                               3900
# 109                                               5070
#
#      median_gross_monthly_income_excluding_employer_cpf
# 0                                                 1800
# 1                                                 1950
# 2                                                 2400
# 3                                                 3300
# 4                                                 5483
# ..                                                 ...
# 105                                               5000
# 106                                               6000
# 107                                               4333
# 108                                               3500
# 109                                               4476
#
# [110 rows x 4 columns]

# %%
# Plot line chart using Plotly Express
fig = px.line(
    df_income,
    x='year',
    y='median_gross_monthly_income_excluding_employer_cpf',
    color='industry',
    title='Median Gross Monthly Income (Excluding Employer CPF) by Industry (2015 Onwards)',
    labels={'year': 'Year', 'industry': 'Industry', 'median_gross_monthly_income_excluding_employer_cpf': 'Median Income (SGD)'},
    color_discrete_sequence = Palette
)

fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Median Income (SGD)',
    legend_title='Industry'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="43e64d1a-6bf4-45e6-9090-2ef714da0adf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43e64d1a-6bf4-45e6-9090-2ef714da0adf")) {                    Plotly.newPlot(                        "43e64d1a-6bf4-45e6-9090-2ef714da0adf",                        [{"hovertemplate":"Industry=Accommodation & Food Services\u003cbr\u003eYear=%{x}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accommodation & Food Services","line":{"color":"#636EFA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Accommodation & Food Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1800,1899,1950,2000,2000,2000,2167,2383,2500,2600],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Administrative & Support Services\u003cbr\u003eYear=%{x}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administrative & Support Services","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Administrative & Support Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1950,2083,2000,2177,2492,2446,2448,2500,2800,2950],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Community, Social & Personal Services\u003cbr\u003eYear=%{x}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Community, Social & Personal Services","line":{"color":"#00CC96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Community, Social & Personal Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2400,2500,2600,2708,2909,2600,3000,3000,3250,3000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Construction\u003cbr\u003eYear=%{x}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Construction","line":{"color":"#AB63FA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Construction","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[3300,3340,3300,3629,3589,3792,3792,4000,4333,4317],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Financial & Insurance Services\u003cbr\u003eYear=%{x}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Financial & Insurance Services","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Financial & Insurance Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[5483,5417,5760,5688,6000,6050,6200,7292,7250,7583],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Information & Communications\u003cbr\u003eYear=%{x}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Information & Communications","line":{"color":"#19D3F3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Information & Communications","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[4792,4569,5000,5000,5300,5417,5311,6000,6400,6500],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Manufacturing\u003cbr\u003eYear=%{x}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Manufacturing","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Manufacturing","orientation":"v","showlegend":true,"x":[2015,201 ...

# %%
# Load CSV
df = pd.read_csv('mrsd_18_Variable_component.csv')

# Filter year range
df = df[df['year'].isin(year_cols)]
df['year'] = df['year'].astype(int)


# Remap industries
mapping = {
    'Wholesale Trade': 'Wholesale & Retail Trade',
    'Retail Trade': 'Wholesale & Retail Trade',
    'Transport And Storage': 'Transportation & Storage',
    'Accommodation': 'Accommodation & Food Services',
    'Food  Beverage Services': 'Accommodation & Food Services',
    'Information And Communications': 'Information & Communications',
    'Financial And Insurance Services': 'Financial & Insurance Services',
    'Real Estate Services': 'Real Estate Services',
    'Professional Services': 'Professional Services',
    'Administrative And Support Services': 'Administrative & Support Services',
    'Community Social And Personal Services': 'Community, Social & Personal Services'
}
df['ind2'] = df['ind2'].replace(mapping)
df = df.groupby(['year','ind2'])['avc'].sum().reset_index()

# Display cleaned
df = df.sort_values(by=['year','ind2']).reset_index(drop=True)
display(df)
# Out:
#      year                                   ind2   avc
# 0    2015          Accommodation & Food Services  3.12
# 1    2015      Administrative & Support Services  1.14
# 2    2015  Community, Social & Personal Services  2.37
# 3    2015                           Construction  1.40
# 4    2015         Financial & Insurance Services  3.38
# ..    ...                                    ...   ...
# 105  2024                          Manufacturing  1.87
# 106  2024                  Professional Services  1.65
# 107  2024                   Real Estate Services  1.98
# 108  2024               Transportation & Storage  2.74
# 109  2024               Wholesale & Retail Trade  3.18
#
# [110 rows x 3 columns]

# %%
# Plot line chart using Plotly Express
fig = px.line(
    df,
    x='year',
    y='avc',
    color='ind2',
    title='Bonus Quantum Paid by Industry Over Years',
    labels={'year': 'Year', 'avc': 'AVC', 'ind2': 'Industry'},
    color_discrete_sequence = Palette
)

fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Annual Variable Component (AVC)',
    legend_title='Industry'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cb5a65be-8671-43ca-aef9-7132399cd075" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb5a65be-8671-43ca-aef9-7132399cd075")) {                    Plotly.newPlot(                        "cb5a65be-8671-43ca-aef9-7132399cd075",                        [{"hovertemplate":"Industry=Accommodation & Food Services\u003cbr\u003eYear=%{x}\u003cbr\u003eAVC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accommodation & Food Services","line":{"color":"#636EFA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Accommodation & Food Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[3.12,3.21,2.97,2.9800000000000004,2.53,1.87,1.71,2.83,2.8200000000000003,2.71],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Administrative & Support Services\u003cbr\u003eYear=%{x}\u003cbr\u003eAVC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administrative & Support Services","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Administrative & Support Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1.14,1.23,1.38,1.07,0.91,0.83,0.72,0.78,0.98,1.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Community, Social & Personal Services\u003cbr\u003eYear=%{x}\u003cbr\u003eAVC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Community, Social & Personal Services","line":{"color":"#00CC96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Community, Social & Personal Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2.37,2.39,2.44,2.36,2.34,2.14,2.06,2.14,2.04,2.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Construction\u003cbr\u003eYear=%{x}\u003cbr\u003eAVC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Construction","line":{"color":"#AB63FA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Construction","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1.4,1.45,1.27,1.11,1.12,0.78,1.02,1.16,1.23,1.22],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Financial & Insurance Services\u003cbr\u003eYear=%{x}\u003cbr\u003eAVC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Financial & Insurance Services","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Financial & Insurance Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[3.38,3.28,3.34,3.13,3.23,3.21,3.14,3.31,3.04,3.07],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Information & Communications\u003cbr\u003eYear=%{x}\u003cbr\u003eAVC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Information & Communications","line":{"color":"#19D3F3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Information & Communications","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2.23,2.03,1.98,1.87,1.5,1.48,1.69,1.78,1.75,1.39],"yaxis":"y","type":"scatter"},{"hovertemplate":"Industry=Manufacturing\u003cbr\u003eYear=%{x}\u003cbr\u003eAVC=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Manufacturing","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Manufacturing","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2.42,2.25,2.28,2.16,1.96,1.8 ...

# %% [markdown]
# # Raghav: Employment by Industry and Job Vacancy

# %%
# Import data
df = pd.read_csv('M184071.csv')

# Clean data
df = df.dropna(thresh=2)
df.columns = ['Data Series'] + list(df.iloc[0, 1:])
df = df.drop(columns=[col for col in df.columns[1:] if '4Q' not in str(col)])
df.columns = ['Data Series'] + [int(col.split()[0]) for col in df.columns[1:]]
df = df[['Data Series'] + year_cols]

# Filter selected industries only
df['Data Series'] = df['Data Series'].str.strip()
df['Data Series'] = df['Data Series'].str.replace('And', '&', regex=False)
df['Data Series'] = df['Data Series'].replace('Community, Social & Personal Services', 'All Services')
df['Data Series'] = df['Data Series'].replace('Other Community, Social & Personal Services', 'Community, Social & Personal Services')
df = df[df['Data Series'].isin(Industries)].reset_index(drop=True)
df = df.replace(['-', 'na', np.nan], 0)
df[year_cols] = df[year_cols].astype(float)
df = df.groupby('Data Series')[year_cols].sum().reset_index()

# Display cleaned
df_vacancies = df.sort_values(by=['Data Series']).reset_index(drop=True)
display(df_vacancies)
# Out:
#                               Data Series    2015    2016    2017    2018  \
# 0           Accommodation & Food Services  6100.0  4900.0  5400.0  6400.0
# 1       Administrative & Support Services  4800.0  4800.0  4200.0  5300.0
# 2   Community, Social & Personal Services  1100.0   500.0   600.0  1200.0
# 3                            Construction  1900.0  1600.0  1600.0  4400.0
# 4          Financial & Insurance Services  3700.0  3400.0  4200.0  4700.0
# 5            Information & Communications  2500.0  2700.0  3100.0  4100.0
# 6                           Manufacturing  6400.0  5200.0  6000.0  7500.0
# 7                   Professional Services  3300.0  2500.0  2600.0  4000.0
# 8                    Real Estate Services  1900.0  1300.0  1100.0  1400.0
# 9                Transportation & Storage  3100.0  2200.0  3000.0  3600.0
# 10               Wholesale & Retail Trade  6300.0  5900.0  5700.0  6000.0
#
#       2019    2020     2021     2022    2023    2024
# 0   6000.0  4300.0   8900.0   9100.0  6800.0  6600.0
# 1   4200.0  3800.0   7200.0   7800.0  5300.0  5500.0
# 2    300.0   900.0   2000.0   2300.0  1800.0  1900.0
# 3   1200.0  4900.0  12400.0   8800.0  6300.0  8400.0
# 4   4600.0  3700.0  13100.0   7700.0  7200.0  5300.0
# 5   4500.0  4900.0  11100.0   8200.0  6300.0  5600.0
# 6   6000.0  5900.0  13800.0  11300.0  8500.0  8200.0
# 7   3400.0  3400.0   8600.0   7900.0  6200.0  5800.0
# 8   1200.0  1000.0   1800.0   2100.0  1900.0  1500.0
# 9   2100.0  2200.0   6900.0   7400.0  5000.0  3800.0
# 10  5400.0  5100.0  10600.0  10500.0  7100.0  6600.0

# %%
# Melt the DataFrame for easier plotting
df_melted = df.melt(id_vars='Data Series', var_name='Year', value_name='Job Vacancies')

# Plot line chart using Plotly Express
fig = px.line(df_melted, x='Year', y='Job Vacancies', color='Data Series',
              title='Job Vacancies By Industry Over Years',
              color_discrete_sequence = Palette)

fig.update_layout(
    xaxis_title='Year',
    yaxis_title='Job Vacancies',
    legend_title='Industry'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90ae83d3-f805-4e81-ba9e-be0a1a758edc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90ae83d3-f805-4e81-ba9e-be0a1a758edc")) {                    Plotly.newPlot(                        "90ae83d3-f805-4e81-ba9e-be0a1a758edc",                        [{"hovertemplate":"Data Series=Accommodation & Food Services\u003cbr\u003eYear=%{x}\u003cbr\u003eJob Vacancies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accommodation & Food Services","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Accommodation & Food Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[6100.0,4900.0,5400.0,6400.0,6000.0,4300.0,8900.0,9100.0,6800.0,6600.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Data Series=Administrative & Support Services\u003cbr\u003eYear=%{x}\u003cbr\u003eJob Vacancies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administrative & Support Services","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Administrative & Support Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[4800.0,4800.0,4200.0,5300.0,4200.0,3800.0,7200.0,7800.0,5300.0,5500.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Data Series=Community, Social & Personal Services\u003cbr\u003eYear=%{x}\u003cbr\u003eJob Vacancies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Community, Social & Personal Services","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Community, Social & Personal Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1100.0,500.0,600.0,1200.0,300.0,900.0,2000.0,2300.0,1800.0,1900.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Data Series=Construction\u003cbr\u003eYear=%{x}\u003cbr\u003eJob Vacancies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Construction","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Construction","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1900.0,1600.0,1600.0,4400.0,1200.0,4900.0,12400.0,8800.0,6300.0,8400.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Data Series=Financial & Insurance Services\u003cbr\u003eYear=%{x}\u003cbr\u003eJob Vacancies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Financial & Insurance Services","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Financial & Insurance Services","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[3700.0,3400.0,4200.0,4700.0,4600.0,3700.0,13100.0,7700.0,7200.0,5300.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Data Series=Information & Communications\u003cbr\u003eYear=%{x}\u003cbr\u003eJob Vacancies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Information & Communications","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Information & Communications","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[2500.0,2700.0,3100.0,4100.0,4500.0,4900.0,11100.0,8200.0,6300.0,5600.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Data Series=Manufacturing\u003cbr\u003eYear=%{x}\u003cbr\u003eJob Vacancies=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Manufacturing","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol" ...

# %%
# Combine job vacany dataset from previous income dataset
df_vacancies_melted = df_vacancies.melt(id_vars='Data Series', var_name='year', value_name='Job Vacancy')
df_income = df_income.rename(columns={'industry': 'Data Series'})
combined_df = pd.merge(df_vacancies_melted, df_income, on=['Data Series', 'year'])

combined_df
# Out:
#                                Data Series  year  Job Vacancy  \
# 0            Accommodation & Food Services  2015       6100.0
# 1        Administrative & Support Services  2015       4800.0
# 2    Community, Social & Personal Services  2015       1100.0
# 3                             Construction  2015       1900.0
# 4           Financial & Insurance Services  2015       3700.0
# ..                                     ...   ...          ...
# 105                          Manufacturing  2024       8200.0
# 106                  Professional Services  2024       5800.0
# 107                   Real Estate Services  2024       1500.0
# 108               Transportation & Storage  2024       3800.0
# 109               Wholesale & Retail Trade  2024       6600.0
#
#      median_gross_monthly_income_including_employer_cpf  \
# 0                                                 2000
# 1                                                 2238
# 2                                                 2662
# 3                                                 3790
# 4                                                 6338
# ..                                                 ...
# 105                                               5850
# 106                                               6900
# 107                                               4908
# 108                                               3900
# 109                                               5070
#
#      median_gross_monthly_income_excluding_employer_cpf
# 0                                                 1800
# 1                                                 1950
# 2                                                 2400
# 3                                                 3300
# 4                                                 5483
# ..                                                 ...
# 105                                               5000
# 106                                               6000
# 107                                               4333
# 108                                               3500
# 109                                               4476
#
# [110 rows x 5 columns]

# %%
# Filter for the latest year
df_lastyear = combined_df[combined_df['year'] == combined_df['year'].max()]

# Create scatter plot using Plotly Express
fig = px.scatter(df_lastyear, x='Job Vacancy', y='median_gross_monthly_income_excluding_employer_cpf', color='Data Series',
                 size='Job Vacancy', hover_name='Data Series',
                 title='Job Vacancy vs. Median Income by Industry',
                 labels={'Data Series': 'Industry', 'median_gross_monthly_income_excluding_employer_cpf': 'Median Income (SGD)'},
                 color_discrete_sequence = Palette)

fig.update_layout(
    xaxis_title='Job Vacancy',
    yaxis_title='Median Income (SGD)',
    legend_title='Industry'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8f986838-8575-4503-8b1c-0084466eca58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f986838-8575-4503-8b1c-0084466eca58")) {                    Plotly.newPlot(                        "8f986838-8575-4503-8b1c-0084466eca58",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eIndustry=Accommodation & Food Services\u003cbr\u003eJob Vacancy=%{marker.size}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Accommodation & Food Services"],"legendgroup":"Accommodation & Food Services","marker":{"color":"#636EFA","size":[6600.0],"sizemode":"area","sizeref":21.0,"symbol":"circle"},"mode":"markers","name":"Accommodation & Food Services","orientation":"v","showlegend":true,"x":[6600.0],"xaxis":"x","y":[2600],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eIndustry=Administrative & Support Services\u003cbr\u003eJob Vacancy=%{marker.size}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Administrative & Support Services"],"legendgroup":"Administrative & Support Services","marker":{"color":"#EF553B","size":[5500.0],"sizemode":"area","sizeref":21.0,"symbol":"circle"},"mode":"markers","name":"Administrative & Support Services","orientation":"v","showlegend":true,"x":[5500.0],"xaxis":"x","y":[2950],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eIndustry=Community, Social & Personal Services\u003cbr\u003eJob Vacancy=%{marker.size}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Community, Social & Personal Services"],"legendgroup":"Community, Social & Personal Services","marker":{"color":"#00CC96","size":[1900.0],"sizemode":"area","sizeref":21.0,"symbol":"circle"},"mode":"markers","name":"Community, Social & Personal Services","orientation":"v","showlegend":true,"x":[1900.0],"xaxis":"x","y":[3000],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eIndustry=Construction\u003cbr\u003eJob Vacancy=%{marker.size}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Construction"],"legendgroup":"Construction","marker":{"color":"#AB63FA","size":[8400.0],"sizemode":"area","sizeref":21.0,"symbol":"circle"},"mode":"markers","name":"Construction","orientation":"v","showlegend":true,"x":[8400.0],"xaxis":"x","y":[4317],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eIndustry=Financial & Insurance Services\u003cbr\u003eJob Vacancy=%{marker.size}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Financial & Insurance Services"],"legendgroup":"Financial & Insurance Services","marker":{"color":"#FFA15A","size":[5300.0],"sizemode":"area","sizeref":21.0,"symbol":"circle"},"mode":"markers","name":"Financial & Insurance Services","orientation":"v","showlegend":true,"x":[5300.0],"xaxis":"x","y":[7583],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eIndustry=Information & Communications\u003cbr\u003eJob Vacancy=%{marker.size}\u003cbr\u003eMedian Income (SGD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Information & Communications"],"legendgroup":"Information & Communications","marker":{"color":"#19D3F3","size":[5600.0],"sizemode":"area","sizeref":21.0,"symbol":"circle"},"mode":"markers","name":"Information & Communicat ...
